# %% [markdown]
# # Notebook Summary
# - Get paraphrase-multilingual-MiniLM-L12-v2 from huggingface
# - Use paraphrase-multilingual-MiniLM-L12-v2 to
#     - extract embeddings from Tweets
#     - extract embeddings from concatenations of Tweet + OCR text

# %% [markdown]
# # 0. Imports and Constants
# - Do not forget to select dataset version in the #CONSTANTS# part

# %%
############## AUTORELOAD MAGIC ###################
# %load_ext autoreload
# %autoreload 2
###################################################

############## FUNDAMENTAL MODULES ################
import json
import os
import sys
import copy
import numpy as np
import pickle
import re
##################################################

############## TASK-SPECIFIC MODULES #############
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from data import TweetNormalizer, utils, feature_extraction
###################################################

############## DATA SCIENCE & ML MODULES ##########
import torch
import pandas as pd
from transformers import AutoModel, AutoTokenizer
from sentence_transformers import SentenceTransformer
from scipy import stats
###################################################

############# CONSTANT DICT KEYS ###################
# Constant dict keys
TRAIN = "train"
DEV = "dev"
TEST = "test"
GOLD = "gold"
TXT = "txt"
IMG = "img"
OCR = "ocr"
TXT_OCR = "txt_ocr"
SPLITS = [TRAIN, DEV, TEST, GOLD]
####################################################

####################### SELECT ###########################
users = ["patriziopalmisano", "onurdenizguler", "jockl"]
user = users[2] # SELECT USER
version = "v2" # SELECT DATASET VERSION
dataset_version = version
##########################################################

if user in users[:2]:
    cw_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive"
    data_dir = f"{cw_dir}/data/CT23_1A_checkworthy_multimodal_english"
    data_dir_with_version = f"{data_dir}_{dataset_version}"
    gold_dir = f"{cw_dir}/data/CT23_1A_checkworthy_multimodal_english_test_gold"

else:
    cw_dir = f"/home/jockl/Insync/check.worthiness@gmail.com/Google Drive"
    data_dir = f"{cw_dir}/data/CT23_1A_checkworthy_multimodal_english"
    data_dir_with_version = f"{data_dir}_{dataset_version}"
    gold_dir = f"{cw_dir}/data/CT23_1A_checkworthy_multimodal_english_test_gold"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Load all Datasets
# First, we extract all the raw texts from the JSON files. Note that the concatenation of tweet and OCR text is realized with a new line in-between.

# %%
# Load the datasets
raw_dataset, tweet_texts, imgs, tweet_ids, ocr_texts, tweet_concat_ocr = utils.load_data_splits_with_gold_dataset(data_dir, version)
# Out:
# Sizes of txt, img, ocr, txt+ocr arrays in train, test, dev, gold:
# 2356 2356 2356 2356
# 271 271 2356 2356
# 548 548 2356 2356
# 736 736 2356 2356

# %%
# Inspect Tweet and OCR concatenation
print(f"Tweet:\n{tweet_texts[TRAIN][6]}")
print(f"\nOCR:\n{ocr_texts[TRAIN][6]}")
print(f"\nConcat:\n{tweet_concat_ocr[TRAIN][6]}")
# Out:
# Tweet:
# Despite calls for calm, some local people are panicking over the deadly coronavirus outbreak.
#
# "I really am. It's really something that I'm really frightened about right now."
#
# "It might be actually worse than what they're telling us."
#
# https://t.co/2aeFCPdg4T https://t.co/Stjz0XlcwA
#
# OCR:
# CORONAVIRUS
# MGN
#
#
# Concat:
# Despite calls for calm, some local people are panicking over the deadly coronavirus outbreak.
#
# "I really am. It's really something that I'm really frightened about right now."
#
# "It might be actually worse than what they're telling us."
#
# https://t.co/2aeFCPdg4T https://t.co/Stjz0XlcwA
# CORONAVIRUS
# MGN

# %% [markdown]
# # 2. Normalize Texts

# %%
# Normalize all tweets using TweetNormalizer()
normalized_tweets = {split: [TweetNormalizer.normalizeTweet(tweet) for tweet in tweet_texts[split]] for split in SPLITS}
normalized_tweet_concat_ocr = {split: [TweetNormalizer.normalizeTweet(concat) for concat in tweet_concat_ocr[split]] for split in SPLITS}
print(len(normalized_tweets[TRAIN]))
print(len(normalized_tweet_concat_ocr[TRAIN]))
# Out:
# 2356
# 2356

# %%
# Inspect normalization of tweets
print(f"Tweet:\n{tweet_texts[TRAIN][6]}")
print(f"\nNormalized Tweet:\n{normalized_tweets[TRAIN][6]}")
# Out:
# Tweet:
# Despite calls for calm, some local people are panicking over the deadly coronavirus outbreak.
#
# "I really am. It's really something that I'm really frightened about right now."
#
# "It might be actually worse than what they're telling us."
#
# https://t.co/2aeFCPdg4T https://t.co/Stjz0XlcwA
#
# Normalized Tweet:
# Despite calls for calm , some local people are panicking over the deadly coronavirus outbreak . " I really am . It 's really something that I 'm really frightened about right now . " " It might be actually worse than what they 're telling us . " HTTPURL HTTPURL

# %%
# Inspect normalization of tweet_ocr_concat
print(f"Concat:\n{tweet_texts[TRAIN][6]}")
print(f"Normalized Concat:\n{normalized_tweet_concat_ocr[TRAIN][6]}")
# Out:
# Concat:
# Despite calls for calm, some local people are panicking over the deadly coronavirus outbreak.
#
# "I really am. It's really something that I'm really frightened about right now."
#
# "It might be actually worse than what they're telling us."
#
# https://t.co/2aeFCPdg4T https://t.co/Stjz0XlcwA
# Normalized Concat:
# Despite calls for calm , some local people are panicking over the deadly coronavirus outbreak . " I really am . It 's really something that I 'm really frightened about right now . " " It might be actually worse than what they 're telling us . " HTTPURL HTTPURL CORONAVIRUS MGN

# %% [markdown]
# # 3. Set Up The Model and Embed A Minimal Example

# %%
# Set up device
device = "cuda" if torch.cuda.is_available() else \
         ("mps" if torch.backends.mps.is_available() else "cpu")

# %%
# Get the model
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2').to(device)

# %%
# Embed one example text
input_text = normalized_tweets[TRAIN][0]
embedding = model.encode(input_text)
print(embedding.shape)
# Out:
# (384,)

# %% [markdown]
# # 4. Embed the Samples

# %% [markdown]
# First, we set the batch size with which the model should embed our data splits.

# %%
# Set batch size and model name here
batch_size = 8
model_name = "paraphrase"

# %% [markdown]
# ## 4.1 Embed the Tweets Only

# %%
# Embed every split
for split in SPLITS:
    utils.embed_and_pickle_split(model, model_name, data_dir_with_version, split, normalized_tweets[split], with_ocr=False, batch_size=batch_size)
# Out:
# Split: train
# Num samples: 2356
# Num batches: 294
# train batch 0/294
# train batch 1/294
# train batch 2/294
# train batch 3/294
# train batch 4/294
# train batch 5/294
# train batch 6/294
# train batch 7/294
# train batch 8/294
# train batch 9/294
# train batch 10/294
# train batch 11/294
# train batch 12/294
# train batch 13/294
# train batch 14/294
# train batch 15/294
# train batch 16/294
# train batch 17/294
# train batch 18/294
# train batch 19/294
# train batch 20/294
# train batch 21/294
# train batch 22/294
# train batch 23/294
# train batch 24/294
# train batch 25/294
# train batch 26/294
# train batch 27/294
# train batch 28/294
# train batch 29/294
# train batch 30/294
# train batch 31/294
# train batch 32/294
# train batch 33/294
# train batch 34/294
# train batch 35/294
# train batch 36/294
# train batch 37/294
# train batch 38/294
# train batch 39/294
# train batch 40/294
# train batch 41/294
# train batch 42/294
# train batch 43/294
# train batch 44/294
# train batch 45/294
# train batch 46/294
# train batch 47/294
# train batch 48/294
# train batch 49/294
# train batch 50/294
# train batch 51/294
# train batch 52/294
# train batch 53/294
# train batch 54/294
# train batch 55/294
# train batch 56/294
# train batch 57/294
# train batch 58/294
# train batch 59/294
# train batch 60/294
# train batch 61/294
# train batch 62/294
# train batch 63/294
# train batch 64/294
# train batch 65/294
# train batch 66/294
# train batch 67/294
# train batch 68/294
# train batch 69/294
# train batch 70/294
# train batch 71/294
# train batch 72/294
# train batch 73/294
# train batch 74/294
# train batch 75/294
# train batch 76/294
# train batch 77/294
# train batch 78/294
# train batch 79/294
# train batch 80/294
# train batch 81/294
# train batch 82/294
# train batch 83/294
# train batch 84/294
# train batch 85/294
# train batch 86/294
# train batch 87/294
# train batch 88/294
# train batch 89/294
# train batch 90/294
# train batch 91/294
# train batch 92/294
# train batch 93/294
# train batch 94/294
# train batch 95/294
# train batch 96/294
# train batch 97/294
# train batch 98/294
# train batch 99/294
# train batch 100/294
# train batch 101/294
# train batch 102/294
# train batch 103/294
# train batch 104/294
# train batch 105/294
# train batch 106/294
# train batch 107/294
# train batch 108/294
# train batch 109/294
# train batch 110/294
# train batch 111/294
# train batch 112/294
# train batch 113/294
# train batch 114/294
# train batch 115/294
# train batch 116/294
# train batch 117/294
# train batch 118/294
# train batch 119/294
# train batch 120/294
# train batch 121/294
# train batch 122/294
# train batch 123/294
# train batch 124/294
# train batch 125/294
# train batch 126/294
# train batch 127/294
# train batch 128/294
# train batch 129/294
# train batch 130/294
# train batch 131/294
# train batch 132/294
# train batch 133/294
# train batch 134/294
# train batch 135/294
# train batch 136/294
# train batch 137/294
# train batch 138/294
# train batch 139/294
# train batch 140/294
# train batch 141/294
# train batch 142/294
# train batch 143/294
# train batch 144/294
# train batch 145/294
# train batch 146/294
# train batch 147/294
# train batch 148/294
# train batch 149/294
# train batch 150/294
# train batch 151/294
# train batch 152/294
# train batch 153/294
# train batch 154/294
# train batch 155/294
# train batch 156/294
# train batch 157/294
# train batch 158/294
# train batch 159/294
# train batch 160/294
# train batch 161/294
# train batch 162/294
# train batch 163/294
# train batch 164/294
# train batch 165/294
# train batch 166/294
# train batch 167/294
# train batch 168/294
# train batch 169/294
# train batch 170/294
# train batch 171/294
# train batch 172/294
# train batch 173/294
# train batch 174/294
# train batch 175/294
# train batch 176/294
# train batch 177/294
# train batch 178/294
# train batch 179/294
# train batch 180/294
# train batch 181/294
# train batch 182/294
# train batch 183/294
# train batch 184/294
# train batch 185/294
# train batch 186/294
# train batch 187/294
# train batch 188/294
# train batch 189/294
# train batch 190/294
# train batch 191/294
# train batch 192/294
# train batch 193/294
# train batch 194/294
# train batch 195/294
# train batch 196/294
# train batch 197/294
# train batch 198/294
# train batch 199/294
# train batch 200/294
# train batch 201/294
# train batch 202/294
# train batch 203/294
# train batch 204/294
# train batch 205/294
# train batch 206/294
# train batch 207/294
# train batch 208/294
# train batch 209/294
# train batch 210/294
# train batch 211/294
# train batch 212/294
# train batch 213/294
# train batch 214/294
# train batch 215/294
# train batch 216/294
# train batch 217/294
# train batch 218/294
# train batch 219/294
# train batch 220/294
# train batch 221/294
# train batch 222/294
# train batch 223/294
# train batch 224/294
# train batch 225/294
# train batch 226/294
# train batch 227/294
# train batch 228/294
# train batch 229/294
# train batch 230/294
# train batch 231/294
# train batch 232/294
# train batch 233/294
# train batch 234/294
# train batch 235/294
# train batch 236/294
# train batch 237/294
# train batch 238/294
# train batch 239/294
# train batch 240/294
# train batch 241/294
# train batch 242/294
# train batch 243/294
# train batch 244/294
# train batch 245/294
# train batch 246/294
# train batch 247/294
# train batch 248/294
# train batch 249/294
# train batch 250/294
# train batch 251/294
# train batch 252/294
# train batch 253/294
# train batch 254/294
# train batch 255/294
# train batch 256/294
# train batch 257/294
# train batch 258/294
# train batch 259/294
# train batch 260/294
# train batch 261/294
# train batch 262/294
# train batch 263/294
# train batch 264/294
# train batch 265/294
# train batch 266/294
# train batch 267/294
# train batch 268/294
# train batch 269/294
# train batch 270/294
# train batch 271/294
# train batch 272/294
# train batch 273/294
# train batch 274/294
# train batch 275/294
# train batch 276/294
# train batch 277/294
# train batch 278/294
# train batch 279/294
# train batch 280/294
# train batch 281/294
# train batch 282/294
# train batch 283/294
# train batch 284/294
# train batch 285/294
# train batch 286/294
# train batch 287/294
# train batch 288/294
# train batch 289/294
# train batch 290/294
# train batch 291/294
# train batch 292/294
# train batch 293/294
# train batch 294/294
# paraphrase_train_v2: (2356, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_train_v2.pickle
#
# Split: dev
# Num samples: 271
# Num batches: 33
# dev batch 0/33
# dev batch 1/33
# dev batch 2/33
# dev batch 3/33
# dev batch 4/33
# dev batch 5/33
# dev batch 6/33
# dev batch 7/33
# dev batch 8/33
# dev batch 9/33
# dev batch 10/33
# dev batch 11/33
# dev batch 12/33
# dev batch 13/33
# dev batch 14/33
# dev batch 15/33
# dev batch 16/33
# dev batch 17/33
# dev batch 18/33
# dev batch 19/33
# dev batch 20/33
# dev batch 21/33
# dev batch 22/33
# dev batch 23/33
# dev batch 24/33
# dev batch 25/33
# dev batch 26/33
# dev batch 27/33
# dev batch 28/33
# dev batch 29/33
# dev batch 30/33
# dev batch 31/33
# dev batch 32/33
# dev batch 33/33
# paraphrase_dev_v2: (271, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_dev_v2.pickle
#
# Split: test
# Num samples: 548
# Num batches: 68
# test batch 0/68
# test batch 1/68
# test batch 2/68
# test batch 3/68
# test batch 4/68
# test batch 5/68
# test batch 6/68
# test batch 7/68
# test batch 8/68
# test batch 9/68
# test batch 10/68
# test batch 11/68
# test batch 12/68
# test batch 13/68
# test batch 14/68
# test batch 15/68
# test batch 16/68
# test batch 17/68
# test batch 18/68
# test batch 19/68
# test batch 20/68
# test batch 21/68
# test batch 22/68
# test batch 23/68
# test batch 24/68
# test batch 25/68
# test batch 26/68
# test batch 27/68
# test batch 28/68
# test batch 29/68
# test batch 30/68
# test batch 31/68
# test batch 32/68
# test batch 33/68
# test batch 34/68
# test batch 35/68
# test batch 36/68
# test batch 37/68
# test batch 38/68
# test batch 39/68
# test batch 40/68
# test batch 41/68
# test batch 42/68
# test batch 43/68
# test batch 44/68
# test batch 45/68
# test batch 46/68
# test batch 47/68
# test batch 48/68
# test batch 49/68
# test batch 50/68
# test batch 51/68
# test batch 52/68
# test batch 53/68
# test batch 54/68
# test batch 55/68
# test batch 56/68
# test batch 57/68
# test batch 58/68
# test batch 59/68
# test batch 60/68
# test batch 61/68
# test batch 62/68
# test batch 63/68
# test batch 64/68
# test batch 65/68
# test batch 66/68
# test batch 67/68
# test batch 68/68
# paraphrase_test_v2: (548, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_test_v2.pickle
#
# Split: gold
# Num samples: 736
# Num batches: 92
# gold batch 0/92
# gold batch 1/92
# gold batch 2/92
# gold batch 3/92
# gold batch 4/92
# gold batch 5/92
# gold batch 6/92
# gold batch 7/92
# gold batch 8/92
# gold batch 9/92
# gold batch 10/92
# gold batch 11/92
# gold batch 12/92
# gold batch 13/92
# gold batch 14/92
# gold batch 15/92
# gold batch 16/92
# gold batch 17/92
# gold batch 18/92
# gold batch 19/92
# gold batch 20/92
# gold batch 21/92
# gold batch 22/92
# gold batch 23/92
# gold batch 24/92
# gold batch 25/92
# gold batch 26/92
# gold batch 27/92
# gold batch 28/92
# gold batch 29/92
# gold batch 30/92
# gold batch 31/92
# gold batch 32/92
# gold batch 33/92
# gold batch 34/92
# gold batch 35/92
# gold batch 36/92
# gold batch 37/92
# gold batch 38/92
# gold batch 39/92
# gold batch 40/92
# gold batch 41/92
# gold batch 42/92
# gold batch 43/92
# gold batch 44/92
# gold batch 45/92
# gold batch 46/92
# gold batch 47/92
# gold batch 48/92
# gold batch 49/92
# gold batch 50/92
# gold batch 51/92
# gold batch 52/92
# gold batch 53/92
# gold batch 54/92
# gold batch 55/92
# gold batch 56/92
# gold batch 57/92
# gold batch 58/92
# gold batch 59/92
# gold batch 60/92
# gold batch 61/92
# gold batch 62/92
# gold batch 63/92
# gold batch 64/92
# gold batch 65/92
# gold batch 66/92
# gold batch 67/92
# gold batch 68/92
# gold batch 69/92
# gold batch 70/92
# gold batch 71/92
# gold batch 72/92
# gold batch 73/92
# gold batch 74/92
# gold batch 75/92
# gold batch 76/92
# gold batch 77/92
# gold batch 78/92
# gold batch 79/92
# gold batch 80/92
# gold batch 81/92
# gold batch 82/92
# gold batch 83/92
# gold batch 84/92
# gold batch 85/92
# gold batch 86/92
# gold batch 87/92
# gold batch 88/92
# gold batch 89/92
# gold batch 90/92
# gold batch 91/92
# paraphrase_gold_v2: (736, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_gold_v2.pickle

# %%
# Embed every split
for split in SPLITS:
    utils.embed_and_pickle_split(model, model_name, data_dir_with_version, split, normalized_tweet_concat_ocr[split], with_ocr=True, batch_size=batch_size)
# Out:
# Split: train
# Num samples: 2356
# Num batches: 294
# train batch 0/294
# train batch 1/294
# train batch 2/294
# train batch 3/294
# train batch 4/294
# train batch 5/294
# train batch 6/294
# train batch 7/294
# train batch 8/294
# train batch 9/294
# train batch 10/294
# train batch 11/294
# train batch 12/294
# train batch 13/294
# train batch 14/294
# train batch 15/294
# train batch 16/294
# train batch 17/294
# train batch 18/294
# train batch 19/294
# train batch 20/294
# train batch 21/294
# train batch 22/294
# train batch 23/294
# train batch 24/294
# train batch 25/294
# train batch 26/294
# train batch 27/294
# train batch 28/294
# train batch 29/294
# train batch 30/294
# train batch 31/294
# train batch 32/294
# train batch 33/294
# train batch 34/294
# train batch 35/294
# train batch 36/294
# train batch 37/294
# train batch 38/294
# train batch 39/294
# train batch 40/294
# train batch 41/294
# train batch 42/294
# train batch 43/294
# train batch 44/294
# train batch 45/294
# train batch 46/294
# train batch 47/294
# train batch 48/294
# train batch 49/294
# train batch 50/294
# train batch 51/294
# train batch 52/294
# train batch 53/294
# train batch 54/294
# train batch 55/294
# train batch 56/294
# train batch 57/294
# train batch 58/294
# train batch 59/294
# train batch 60/294
# train batch 61/294
# train batch 62/294
# train batch 63/294
# train batch 64/294
# train batch 65/294
# train batch 66/294
# train batch 67/294
# train batch 68/294
# train batch 69/294
# train batch 70/294
# train batch 71/294
# train batch 72/294
# train batch 73/294
# train batch 74/294
# train batch 75/294
# train batch 76/294
# train batch 77/294
# train batch 78/294
# train batch 79/294
# train batch 80/294
# train batch 81/294
# train batch 82/294
# train batch 83/294
# train batch 84/294
# train batch 85/294
# train batch 86/294
# train batch 87/294
# train batch 88/294
# train batch 89/294
# train batch 90/294
# train batch 91/294
# train batch 92/294
# train batch 93/294
# train batch 94/294
# train batch 95/294
# train batch 96/294
# train batch 97/294
# train batch 98/294
# train batch 99/294
# train batch 100/294
# train batch 101/294
# train batch 102/294
# train batch 103/294
# train batch 104/294
# train batch 105/294
# train batch 106/294
# train batch 107/294
# train batch 108/294
# train batch 109/294
# train batch 110/294
# train batch 111/294
# train batch 112/294
# train batch 113/294
# train batch 114/294
# train batch 115/294
# train batch 116/294
# train batch 117/294
# train batch 118/294
# train batch 119/294
# train batch 120/294
# train batch 121/294
# train batch 122/294
# train batch 123/294
# train batch 124/294
# train batch 125/294
# train batch 126/294
# train batch 127/294
# train batch 128/294
# train batch 129/294
# train batch 130/294
# train batch 131/294
# train batch 132/294
# train batch 133/294
# train batch 134/294
# train batch 135/294
# train batch 136/294
# train batch 137/294
# train batch 138/294
# train batch 139/294
# train batch 140/294
# train batch 141/294
# train batch 142/294
# train batch 143/294
# train batch 144/294
# train batch 145/294
# train batch 146/294
# train batch 147/294
# train batch 148/294
# train batch 149/294
# train batch 150/294
# train batch 151/294
# train batch 152/294
# train batch 153/294
# train batch 154/294
# train batch 155/294
# train batch 156/294
# train batch 157/294
# train batch 158/294
# train batch 159/294
# train batch 160/294
# train batch 161/294
# train batch 162/294
# train batch 163/294
# train batch 164/294
# train batch 165/294
# train batch 166/294
# train batch 167/294
# train batch 168/294
# train batch 169/294
# train batch 170/294
# train batch 171/294
# train batch 172/294
# train batch 173/294
# train batch 174/294
# train batch 175/294
# train batch 176/294
# train batch 177/294
# train batch 178/294
# train batch 179/294
# train batch 180/294
# train batch 181/294
# train batch 182/294
# train batch 183/294
# train batch 184/294
# train batch 185/294
# train batch 186/294
# train batch 187/294
# train batch 188/294
# train batch 189/294
# train batch 190/294
# train batch 191/294
# train batch 192/294
# train batch 193/294
# train batch 194/294
# train batch 195/294
# train batch 196/294
# train batch 197/294
# train batch 198/294
# train batch 199/294
# train batch 200/294
# train batch 201/294
# train batch 202/294
# train batch 203/294
# train batch 204/294
# train batch 205/294
# train batch 206/294
# train batch 207/294
# train batch 208/294
# train batch 209/294
# train batch 210/294
# train batch 211/294
# train batch 212/294
# train batch 213/294
# train batch 214/294
# train batch 215/294
# train batch 216/294
# train batch 217/294
# train batch 218/294
# train batch 219/294
# train batch 220/294
# train batch 221/294
# train batch 222/294
# train batch 223/294
# train batch 224/294
# train batch 225/294
# train batch 226/294
# train batch 227/294
# train batch 228/294
# train batch 229/294
# train batch 230/294
# train batch 231/294
# train batch 232/294
# train batch 233/294
# train batch 234/294
# train batch 235/294
# train batch 236/294
# train batch 237/294
# train batch 238/294
# train batch 239/294
# train batch 240/294
# train batch 241/294
# train batch 242/294
# train batch 243/294
# train batch 244/294
# train batch 245/294
# train batch 246/294
# train batch 247/294
# train batch 248/294
# train batch 249/294
# train batch 250/294
# train batch 251/294
# train batch 252/294
# train batch 253/294
# train batch 254/294
# train batch 255/294
# train batch 256/294
# train batch 257/294
# train batch 258/294
# train batch 259/294
# train batch 260/294
# train batch 261/294
# train batch 262/294
# train batch 263/294
# train batch 264/294
# train batch 265/294
# train batch 266/294
# train batch 267/294
# train batch 268/294
# train batch 269/294
# train batch 270/294
# train batch 271/294
# train batch 272/294
# train batch 273/294
# train batch 274/294
# train batch 275/294
# train batch 276/294
# train batch 277/294
# train batch 278/294
# train batch 279/294
# train batch 280/294
# train batch 281/294
# train batch 282/294
# train batch 283/294
# train batch 284/294
# train batch 285/294
# train batch 286/294
# train batch 287/294
# train batch 288/294
# train batch 289/294
# train batch 290/294
# train batch 291/294
# train batch 292/294
# train batch 293/294
# train batch 294/294
# paraphrase_with_ocr_train_v2: (2356, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_with_ocr_train_v2.pickle
#
# Split: dev
# Num samples: 271
# Num batches: 33
# dev batch 0/33
# dev batch 1/33
# dev batch 2/33
# dev batch 3/33
# dev batch 4/33
# dev batch 5/33
# dev batch 6/33
# dev batch 7/33
# dev batch 8/33
# dev batch 9/33
# dev batch 10/33
# dev batch 11/33
# dev batch 12/33
# dev batch 13/33
# dev batch 14/33
# dev batch 15/33
# dev batch 16/33
# dev batch 17/33
# dev batch 18/33
# dev batch 19/33
# dev batch 20/33
# dev batch 21/33
# dev batch 22/33
# dev batch 23/33
# dev batch 24/33
# dev batch 25/33
# dev batch 26/33
# dev batch 27/33
# dev batch 28/33
# dev batch 29/33
# dev batch 30/33
# dev batch 31/33
# dev batch 32/33
# dev batch 33/33
# paraphrase_with_ocr_dev_v2: (271, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_with_ocr_dev_v2.pickle
#
# Split: test
# Num samples: 548
# Num batches: 68
# test batch 0/68
# test batch 1/68
# test batch 2/68
# test batch 3/68
# test batch 4/68
# test batch 5/68
# test batch 6/68
# test batch 7/68
# test batch 8/68
# test batch 9/68
# test batch 10/68
# test batch 11/68
# test batch 12/68
# test batch 13/68
# test batch 14/68
# test batch 15/68
# test batch 16/68
# test batch 17/68
# test batch 18/68
# test batch 19/68
# test batch 20/68
# test batch 21/68
# test batch 22/68
# test batch 23/68
# test batch 24/68
# test batch 25/68
# test batch 26/68
# test batch 27/68
# test batch 28/68
# test batch 29/68
# test batch 30/68
# test batch 31/68
# test batch 32/68
# test batch 33/68
# test batch 34/68
# test batch 35/68
# test batch 36/68
# test batch 37/68
# test batch 38/68
# test batch 39/68
# test batch 40/68
# test batch 41/68
# test batch 42/68
# test batch 43/68
# test batch 44/68
# test batch 45/68
# test batch 46/68
# test batch 47/68
# test batch 48/68
# test batch 49/68
# test batch 50/68
# test batch 51/68
# test batch 52/68
# test batch 53/68
# test batch 54/68
# test batch 55/68
# test batch 56/68
# test batch 57/68
# test batch 58/68
# test batch 59/68
# test batch 60/68
# test batch 61/68
# test batch 62/68
# test batch 63/68
# test batch 64/68
# test batch 65/68
# test batch 66/68
# test batch 67/68
# test batch 68/68
# paraphrase_with_ocr_test_v2: (548, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_with_ocr_test_v2.pickle
#
# Split: gold
# Num samples: 736
# Num batches: 92
# gold batch 0/92
# gold batch 1/92
# gold batch 2/92
# gold batch 3/92
# gold batch 4/92
# gold batch 5/92
# gold batch 6/92
# gold batch 7/92
# gold batch 8/92
# gold batch 9/92
# gold batch 10/92
# gold batch 11/92
# gold batch 12/92
# gold batch 13/92
# gold batch 14/92
# gold batch 15/92
# gold batch 16/92
# gold batch 17/92
# gold batch 18/92
# gold batch 19/92
# gold batch 20/92
# gold batch 21/92
# gold batch 22/92
# gold batch 23/92
# gold batch 24/92
# gold batch 25/92
# gold batch 26/92
# gold batch 27/92
# gold batch 28/92
# gold batch 29/92
# gold batch 30/92
# gold batch 31/92
# gold batch 32/92
# gold batch 33/92
# gold batch 34/92
# gold batch 35/92
# gold batch 36/92
# gold batch 37/92
# gold batch 38/92
# gold batch 39/92
# gold batch 40/92
# gold batch 41/92
# gold batch 42/92
# gold batch 43/92
# gold batch 44/92
# gold batch 45/92
# gold batch 46/92
# gold batch 47/92
# gold batch 48/92
# gold batch 49/92
# gold batch 50/92
# gold batch 51/92
# gold batch 52/92
# gold batch 53/92
# gold batch 54/92
# gold batch 55/92
# gold batch 56/92
# gold batch 57/92
# gold batch 58/92
# gold batch 59/92
# gold batch 60/92
# gold batch 61/92
# gold batch 62/92
# gold batch 63/92
# gold batch 64/92
# gold batch 65/92
# gold batch 66/92
# gold batch 67/92
# gold batch 68/92
# gold batch 69/92
# gold batch 70/92
# gold batch 71/92
# gold batch 72/92
# gold batch 73/92
# gold batch 74/92
# gold batch 75/92
# gold batch 76/92
# gold batch 77/92
# gold batch 78/92
# gold batch 79/92
# gold batch 80/92
# gold batch 81/92
# gold batch 82/92
# gold batch 83/92
# gold batch 84/92
# gold batch 85/92
# gold batch 86/92
# gold batch 87/92
# gold batch 88/92
# gold batch 89/92
# gold batch 90/92
# gold batch 91/92
# paraphrase_with_ocr_gold_v2: (736, 384)
# Pickled the embeddings: /home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_v2/paraphrase_with_ocr_gold_v2.pickle

# %% [markdown]
# # 6. Load the Pickled Embeddings
# Example Usage:

# %%
# Load embedding tensor of one data split from pickle file
pickle_file = f"{data_dir_with_version}/{model_name}_{TRAIN}_{dataset_version}.pickle"
with open(pickle_file, 'rb') as handle:
    embeddings_tensor = pickle.load(handle)
    print(embeddings_tensor.shape)
# Out:
# (2356, 384)
