# %%
############## AUTORELOAD MAGIC ###################
# %load_ext autoreload
# %autoreload 2
###################################################

############## FUNDAMENTAL MODULES ################
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import json
from PIL import Image

 ##################################################

############## TASK-SPECIFIC MODULES ##############
sys.path.append("..")
sys.path.append("../..")
from ml.datasets import VanillaDataset
from ml.models import VanillaNN
from ml.trainer import Trainer
from ml.eval import get_output_scores
from data import utils
from analysis.utils import extract_datapoints
###################################################


####################### CONSTANTS ########################
SPLITS = ["train", "dev", "test", "gold"]
TRAIN, DEV, TEST, TXT, IMG = "train", "dev", "test", "txt", "img"
FE_METHODS = ["txt_embeddings", "img_embeddings", "concat", "sum", "mean", "hadamard", "paraphrase"]
TRAIN, DEV, TEST, GOLD = "train", "dev", "test", "gold"
#FE_METHODS += ["concat_cos", "sum_cos", "mean_cos", "hadamard_cos"]
##########################################################

############## DATA SCIENCE & ML MODULES #################
from torch.utils.data import DataLoader
import torch
from sklearn.metrics import classification_report
import pandas as pd
##########################################################

####################### SELECT ###########################
users = ["patriziopalmisano", "onurdenizguler", "jockl"]
user = users[1] # SELECT USER
version = "v2" # SELECT DATASET VERSION
dataset_version = version
##########################################################

if user in users[:2]:
    data_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive/data/CT23_1A_checkworthy_multimodal_english_{version}"
    cw_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive"

else:
    data_dir = f"/home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_{dataset_version}"
    cw_dir = "/home/jockl/Insync/check.worthiness@gmail.com/Google Drive"

features_dir = f"{data_dir}/features"
labels_dir = f"{data_dir}/labels"
models_dir = f"{cw_dir}/models/vanillann_hyperparam_search"
evals_dir = f"{models_dir}/gold_evals"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive/data/CT23_1A_checkworthy_multimodal_english"
raw_dataset, texts, imgs, tweet_ids, ocr_texts, tweet_concat_ocr = utils.load_data_splits_with_gold_dataset(dataset_dir, version)
# Out:
# Sizes of txt, img, ocr, txt+ocr arrays in train, test, dev, gold:
# 2356 2356 2356 2356
# 271 271 2356 2356
# 548 548 2356 2356
# 736 736 2356 2356

# %%
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %%
image_captions = {
    "gold": []
}

for raw_image in imgs["gold"]:
    # unconditional image captioning
    inputs = processor(raw_image, return_tensors="pt")
    out = model.generate(**inputs, max_new_tokens=20)
    caption= processor.decode(out
    [0], skip_special_tokens=True)
    image_captions["gold"].append(caption)

# %%
image_captions["gold"]
# Out:
# ['a woman in a striped shirt is dancing',
#  'energypi - energypig - energypig - energypig - energypig - energy',
#  'a digital painting of a man with a beard',
#  'a woman walks past a shop in the city of vienna',
#  'a graph of the bitcoin market',
#  'a man and woman are on a news set',
#  'a large room with many blue blankets on the floor',
#  'people wearing masks walk through an airport terminal',
#  'a map of the united with the states highlighted in red',
#  'a bar chart showing the number of extreme weather events',
#  'a plane is parked at an airport at night',
#  'bitcoin bitcoin bitcoin bitcoin bitcoin bitcoin bitco',
#  'a blue face mask on a white background',
#  'a map showing the temperature of the earth',
#  "a map showing the percentage of uk's population",
#  'table showing the number of people who have been diagnosed',
#  "volvo's new volvo car is the first to be equipped with a new led",
#  'bitcoin crypt trading platform',
#  'a man is dumping a pile of palm leaves',
#  'the logo for the competition competition, with a colorful background and a colorful geometric design',
#  'the kt app is shown in the image',
#  'a man in a suit and tie speaking at a podium',
#  'a man sitting on a couch in front of a television set',
#  'a person holding a cell phone in their hands',
#  'a child wearing a mask and glasses',
#  'a screen showing the message to the customer',
#  'a woman in a yellow shirt and orange shirt is putting something into a pot',
#  'two girls wearing face masks with hearts on them',
#  'hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello',
#  'a black and white logo with the words poinut',
#  'a letter from the university of california requesting that the school is not open',
#  'arctic ice extent map',
#  'a man in a suit and tie with a stack of coins',
#  'going change sustainable development through coding with microsoft',
#  'a stage with a large screen and people sitting on it',
#  'a graph graph shows the number of people who have been diagnosed',
#  'a group of people holding signs in front of a building',
#  'a text message from a woman who is asking her to be a man',
#  'a screenshot of a sniper in the desert',
#  "the evolution of the earth's crust",
#  'hua presents women in technology',
#  'technical data management',
#  'wind turbines in the desert',
#  'bitcoin investment cycle',
#  'a man holding a banana in his hand',
#  'a screenshot of a text message with the words in chinese',
#  'a man in a white shirt is talking to someone',
#  'a group of people standing in front of a building',
#  'a large tree with green leaves and branches',
#  'firefighters ex with hoses exting a fire in the forest',
#  "the screen with the text'i's not here '",
#  "there are some of the world's most digital digital art",
#  'the event is held in the office of the event',
#  'a man in a black shirt and a white helmet holding a gun',
#  'a tweet tweet tweet tweet tweet tweet t',
#  'a woman in a mask and gloves with the words safe and effective covid vas for canadians',
#  'a table topped with a variety of fabric pieces',
#  'a robot holding a birthday cake and balloons',
#  'a wolf and a wolf with fangs on their mouths',
#  'coronavirus in arizona',
#  'a group of people standing around a tractor',
#  'a picture of two footprints in a frame',
#  'a group of people standing in a room',
#  'a screenshot of a stock chart with the red arrow pointing up',
#  'the settings of the app',
#  'a man standing in a dark room looking out the window',
#  'the canadian healthcare sector is the largest in canada',
#  'a map with the percentage of people living in each country',
#  'a twitter message with the capt that reads what happened??????????',
#  'a man sitting at a desk with a flag behind him',
#  'two men standing next to a car with a box of food',
#  'techipc - breakthrough challenge 2019',
#  'a satellite image of the fire in the area',
#  'the interior of the temple of hatshet',
#  'a woman washing her hands in a blue bucket',
#  'pope benedicto waves to the crowd as he arrives for his weekly audience at the vaticano cathedral in',
#  'a graph showing the number of people who have been in the uk',
#  'a plot with a line graph and a line graph',
#  'love blooms by jennifer ewe',
#  "a plane flying through the sky with the words'i love you '",
#  'a woman wearing a mask with a white face covering her mouth',
#  'google search results',
#  'a man in a suit holding up a piece of paper',
#  'three women with green hair and sunglasses on their heads',
#  'a poster with a number of different types of the philippines',
#  'a black and yellow website with a photo of a man in a suit',
#  'a man in a suit and tie with a pig mask on his face',
#  'the logo for the south africa campaign',
#  'a laptop with a world map on it',
#  "the world's most and most infos info infographic info info info info info info info info",
#  'a man in a suit and tie with a red light on his face',
#  'a white box with a purple box on it',
#  'a corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona',
#  "bjp's chief, shrian reddy reddy reddy reddy reddy reddy reddy reddy reddy reddy reddy reddy reddy",
#  'a dry field with a tree in the middle',
#  'get ready to rumble wrestling',
#  'a truck parked in a parking lot with mountains in the background',
#  'three women standing in front of a map',
#  'a robot with a blue light on its face',
#  'a painting of ships in a body of water',
#  'a spider is sitting on a spider web',
#  'a graphic showing the percentage of greenhouse greenhouses in the world',
#  'a large building with a red roof and a blue sky',
#  'a 3d landscape with a lot of blue and green',
#  'the logo for the global organization',
#  'a poster with different types of the different types of the plane',
#  'a man in a white shirt is holding a microphone',
#  'how to support your business',
#  'a diagram of a tree with a red dot',
#  'the digital resre',
#  'a hand holding a google logo',
#  'a letter from the president of the united states',
#  'a black background with the words thirty years ago, we have been planet',
#  'a person in a black jacket and a purple jacket with a cat on it',
#  'a screen shot of a bat',
#  'a letter from the chinese language department',
#  'the medical market is estimated to be $ 8 billion in 2012 and projected to reach $ 8 billion in',
#  "we'llucing in may 0820",
#  'people are gathered outside a building to buy food',
#  'a man holding a lit candle in his hand',
#  'a cartoon character with a cigarette in his mouth',
#  'a flyer for the event with a photo of a barbecue grill',
#  'a red car parked on the side of a street',
#  'the ama team on the web',
#  'the cover of the book, the book of the sea',
#  'a dark tunnel with a light coming from the end',
#  'stay safe with stay safe with stay safe with stay safe with stay safe with stay safe with stay safe',
#  'an image of a family on the twitter',
#  "the text on the screen reads,'time '",
#  'a list of the different types of the internet',
#  'a river running through a lush green valley',
#  'president donald trump and president bider',
#  'the logo for switch2sdi',
#  'a man in a suit and tie sitting at a desk',
#  'word vs virus',
#  'a man in a suit and tie is speaking into a microphone',
#  'women in tech will be more european than than than than than than than than than than than than than',
#  'the diagram of the data processing process',
#  'a red, white and blue striped background',
#  "the world's biggest women in tech",
#  'a woman in a red costume and boots',
#  'corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona',
#  'the diagram shows the different layers of the system',
#  'a poster with the words novel coronas and a photo of people in a room',
#  'the upcoming upcoming event is coming to the upcoming event',
#  'a girl in a field of chers',
#  'a graph showing the number of foreign foreign foreign foreign foreign foreign foreign foreign foreign foreign foreign foreign foreign foreign',
#  "a police officer points a gun at a protest in hong's central district",
#  'a man in a suit and tie is talking into a microphone',
#  'a map showing the locations of the area where the fire occurred',
#  'the three girls are standing in front of a purple sky',
#  'radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio radio',
#  'a graph shows how the canadian government is spending',
#  'a poem written in black ink on a pink background',
#  'a row of solar panels',
#  'vegabeuse - vega vega vega vega vega vega vega vega vega vega vega vega vega vega vega vega',
#  'two light bulbs are connected to a machine',
#  "bill gates quote on the world's biggest drug",
#  'a group of people in scrubs and masks',
#  'a map shows the average temperature of smoke in the united',
#  'a man in a suit and tie with the words virus origins',
#  'a man in a uniform is talking to someone',
#  'a video game with a bunch of flowers',
#  'two men in a field of plants',
#  'biton trading system',
#  'two women in black shirts standing next to a sign',
#  'a dog wearing a banda banda and a christmas orname',
#  '1 lakh case in india new day active cases cos 1 lakh 1 points',
#  'people sitting on the beach at sunset',
#  'breaking news with corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona corona',
#  'a woman is pouring water from a bucket',
#  'a man wearing glasses is seen in this screen shot',
#  "a tweet with the capt that reads,'this is important to all the masc",
#  'figure 1 feeds in climate systems',
#  'a quote that reads, ` ` ` ` ` ` ` ` ` ` ` ` ` ` `',
#  'get ready to reate an announcement',
#  'a group of women in a corn field',
#  'the sun setting over the hills in the yorkshire countryside',
#  'three men sitting at a table with one man in the middle',
#  'cies4me 2018 - the future of us',
#  'strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic strategic',
#  'water droplets on a leaf',
#  'a man and woman wearing masks in front of a tv',
#  'a man in a suit and hat sitting at a desk with a computer',
#  'a man in a suit and tie speaking into a microphone',
#  'a stack of boxes with chinese flags on them',
#  'a poster for the smart car smart city event',
#  'a map showing the location of the chinese city of wuzhou',
#  'a gold coin with the words nl listing',
#  'no core required to make it easy to play with a simple game',
#  'a scientist in a lab',
#  'a man with a beard and a shirt on, covering his face',
#  'two men sitting in chairs talking to each other men',
#  'a table with the number of different types of the different types of the different types of the different types',
#  'cim marketplace logo',
#  'a newspaper article with a photo of a man in a suit',
#  'the logo for the car club',
#  'a woman in a black jacket is talking to someone',
#  'a man in a wheelchair with a woman in the background',
#  'four people sitting on stage in front of a screen',
#  'a bird is perched on a branch in the woods',
#  'a red, white and blue striped background',
#  'a diagram showing the symptoms of the respiratory',
#  'traffic jam in the city of los on friday, oct 11, 2012',
#  'cityscapet cityscapet cityscapet cityscapet cityscapet',
#  'the infos logo and the names of the various companies',
#  'a construction site with a bull and a bull',
#  'pokemon wallpapers hd wallpapers hd wallpapers',
#  'google search results',
#  'a graphic showing the differences between the water and the water surface',
#  'a refrigerator sitting on top of a green field',
#  'a man in a suit and tie is shown on a screen',
#  'the mrna pathway of the human and the mitochondrial',
#  'people standing on the sidewalk in front of a building',
#  "a group of women walking on a rock with the words climate change is a women's use",
#  'a cell phone and a tablet with a keyboard',
#  'prime modi modi at the national assembly in new delhi',
#  'a poster with the words it takes 9 months to go out the atmosphere',
#  'a large glacier with a blue sky and white clouds',
#  'a group of people sitting around a table',
#  'a man in a white suit standing next to a woman',
#  'a bat is laying on a pink blanket',
#  'a city with tall buildings and a sky',
#  'a chart showing the price of the stock',
#  'a green icon set with the words and icons',
#  'a woman standing on a stage in front of a screen',
#  'a group of people sitting at desks in front of a projector screen',
#  'a man standing in front of a large screen',
#  'a group of men sitting around a table',
#  'a video chat with a man on the screen',
#  "a man with glasses and a tie, with the words'u - mh'in the middle",
#  'a man takes a photograph of a graffiti artist in the streets of the city',
#  "the logo for the project, with the words,'project,'and'project, '",
#  'a circuit with a circuit and a circuit in the middle',
#  'a map of the country of new zealand',
#  'a man in a white shirt and a white t - shirt with the words you can do it on',
#  'a robot robot with a pink light on its face',
#  'a red, white and blue striped background',
#  'a group of people sitting around a table',
#  'a man in a yellow vest is standing next to an airplane',
#  'earth with a black background and a white border',
#  'a man standing in a field with a dog',
#  'a bird flying in the sky at sunset',
#  'a man sitting on a bench with a dog',
#  'water flowing from a fa fa fa fa fa fa fa fa fa fa fa fa fa fa fa fa',
#  'a woman is crying and holding her nose',
#  'as a layer - driven multi - platform, the multi - platform is a multi - platform for multi',
#  'a pile of silver fish',
#  'a man in a suit and tie is talking to the camera',
#  "a poster with the words,'the end of the world'and a photo of two men wearing",
#  'the flyer for the event',
#  'a crowd of people walking down a street with the words corona corona corona corona corona corona corona corona corona',
#  'the website for the national health service',
#  'a group of people standing in a field',
#  'a sign that reads women for climate justice',
#  'a drawing of an angel with wings',
#  "a car with a sticker on it's hood",
#  'a diagram showing the different types of a smart device',
#  'a baby is sitting in a chair with a stuffed animal',
#  'a painting of a beach with grass and clouds',
#  'a sunset with a quote from person',
#  'the case report of the case',
#  'five steps to create a diagram',
#  'a video of a man walking down a street',
#  'a woman standing at a podium in front of a crowd',
#  'a plane is on the runway at an airport',
#  'a woman standing on top of a mountain',
#  'the text in the article is a very interesting and interesting way to describe the text',
#  'the view from the top of the mountain',
#  'a man in a suit and tie with the words, ` ` ` ` ` ` ` ` `',
#  'the 3d model of a house in the game',
#  "a map showing the routes of the world's most airliness",
#  'a man and woman standing on a boat',
#  'a man standing at a podium in front of a crowd',
#  'a poster with the words, what is the corona??????????',
#  'a small plane flying through the sky',
#  'the article in the paper',
#  'soil change in the climate zone',
#  'the logo for the new mmr',
#  'a man is sitting in front of a television screen',
#  'a comic book with a cat on it',
#  'a turtle on the beach at sunset',
#  "a poster with the words,'the art of the butterfly '",
#  "a forest with a quote that reads,'fire at least 20, 000 acres will occur 5 percent",
#  'samsung logo',
#  'the trail up to the summit of the mountain',
#  'a man and woman are holding a plaque',
#  'a screenshot of a man in a suit and tie, with a woman in a white dress and',
#  'the front cover of the issue of christianity magazine',
#  'a cartoon depicting a woman in a hospital bed with a corona corona corona corona corona corona corona corona corona',
#  'the core element of the core element core element core element element element element element element element element element element',
#  'a green leaf with a bar chart on it',
#  'the timeline of the time of cor',
#  'a man in a suit and tie is standing in front of a wall',
#  'the table of the different types of the different types of the different types of the different types of the',
#  'be good digital citizen poster',
#  'a person in a white suit and blue gloves',
#  'types of smart contracts',
#  'wind turbines in a field',
#  'table 2 the number of different types of hypostecine and hypostecinc',
#  'a group of people sitting at a table',
#  'a cartoon character with a gold trophy and a cartoon character with a gold trophy',
#  'a phone with a credit card and a christmas present',
#  'a woman wearing a face mask crosses a street in wuzhou, china, on march 29',
#  'a logo for a company that sells digital products',
#  'the chart of the stock market showing the price of the stock',
#  'a group of people holding signs and holding signs',
#  'a stop sign with the words climate change is a tax lie',
#  'coronaviruss are the most common form of coronavirus',
#  'a picture of a room with a red carpet and a black wall',
#  "hong police officers are seen in the lobby of hong's hong international airport",
#  'a map of the world with the names of countries',
#  'a map showing the number of corona cases in the world',
#  "a car with the words `''''''''''''''",
#  'a man with a beard and a beard on his head',
#  'a group of people sitting at a podium',
#  'a man sitting on the ground surrounded by a large group of people',
#  'mangrove trees in the water',
#  'a man climbing up a mountain with a rope',
#  'cities for resturas and the sustainable development',
#  'a worker walks on a roof of a solar power plant in the outskirts of ahmedabad, india, june',
#  'a woman is sitting in front of a television',
#  'a house is seen in the middle of a road in the town of sela, california',
#  'a black and white photo of ice on the beach with the words climate is happening',
#  'the ice is melting off the coast of the arctic ocean',
#  'a flyer for the african business',
#  'a sign that says we do',
#  'the logo for the xdx',
#  'a poster with the numbers of the countries',
#  'a woman with her hands up and a speech bubble above her',
#  'a flyer for the climate change conference',
#  'two men in suits and ties are talking on the set',
#  'the star trek, from the original star trek series',
#  'the fore on the fore - trading platform',
#  'a shadow of a man in a hat',
#  "a man in a suit and glasses sits in front of a white screen with the word'e -",
#  'a graph of the bitcon block',
#  'a laptop with a video on it',
#  'two men in suits and masks standing in a room',
#  'a man in a suit and tie with a white background',
#  'a red fire truck parked in a parking',
#  'a man in a suit and tie holding a glass',
#  'a person looking at a computer screen',
#  'the logo for the trade and trade sector',
#  'a computer with a santa hat on it',
#  'a car with a man on the back of it',
#  'a woman in a white shirt and pink shirt stands at a podium with a microphone',
#  'a man in a suit and tie sitting down',
#  'a poster with a photo of children using a laptop',
#  'a black background with a white and red flower',
#  'a man in a suit and tie sitting at a desk',
#  'people wearing protective gear wait to board a train at a railway station in wuzhou county, china,',
#  'the arctic circle with the arctic circle in the middle',
#  'a man with blonde hair and a white shirt laughing',
#  'our common health has always been linked to protecting the water drink and the air breathe',
#  "cnn's chris cuney on coronavirus",
#  "the yahoo app shows the user's name and the location of the yahoo",
#  'the chest is shown with a small, white, and black chest',
#  'a man in a white shirt and blue shorts running',
#  "an event with a photo of a man in a suit and a red background with the words's",
#  'three framed prints of blue and green on a white background',
#  'a quote from the ocean with a quote that reads we must to raise climate',
#  'a man in a suit and tie speaking into a microphone',
#  'the news on the app shows doctors working in the hospital',
#  'sierra nevada region report',
#  'a cartoon character with a quote on it',
#  'canadian cyber security open letter to organizations about ransomware',
#  'the explosion occurred in the area of the city of santa, california',
#  'a blue background with a graduation cap and the words, mile on crimson',
#  'a man wearing a mask is speaking into microphones',
#  'a table with the numbers of different types of the different types of the table',
#  'a man kneeling down in a field with a cane',
#  'two people are playing guitars in a room',
#  'a purple and blue mask with the words pre - orders',
#  'new digital health industry',
#  'a twitter post showing the message that was posted by the indian government',
#  'a bitcoin coin on top of a hundred dollar',
#  'four different types of re re re re re re re re re re re re re re re re',
#  'a cartoon character riding on a lion',
#  'a woman in a yellow jacket and black top holding a laptop',
#  'a graph graph with a line graph',
#  'a person putting a bottle of water into a cardboard box',
#  'a group of reindeers running through the snow',
#  'green man the ultimate guide to the marvel universe by person',
#  'smart city with smart devices and smart devices',
#  'the top 10 healthcare companies in the world',
#  'a poster of a man with a face mask',
#  'a graph graph showing the number of bittots',
#  'a nurse in protective gear is seen in a hospital room',
#  'solar panels on the roof of a building',
#  'the email page for the website',
#  'a hand holding a bottle of cleaning products',
#  'urgent - logo design by the logo company',
#  'a busy street filled with people and buses',
#  'a small plane is parked on the runway',
#  'a map of the area where the plane was flying',
#  'what is blockchain?',
#  'a group of people in a flooded area holding a banner',
#  'the canadian energy market',
#  'a couple wearing masks with the words stand with meds',
#  'paris, france, eiff tower',
#  'bitcoin bitcoin bitcoin bitcoin bitcoin bitcoin bitco',
#  'a man in a room with books and a microphone',
#  'a man skating on an ice rink',
#  'a group of people standing around a car',
#  'a man sitting on a ledge in front of a citysca',
#  'a field with a sign that says the future of the world',
#  'a graphic showing the symptoms of covidd',
#  'a group of people playing hockey on a snowy field',
#  'a crowd of people standing in a field with the words, the next public raise wisey',
#  'a child is playing with a blue stove',
#  'a diagram showing the different parts of a framework',
#  'urgent - logo design by the logo company',
#  'a beach with a hut and a man walking in the water',
#  'a plate of food with broiled tomatoes and broiled broiled broiled broiled broiled bro',
#  'corv covidd update - april 2020',
#  'social media workshop - making finance work for women & state actors',
#  'evo 8 days',
#  'the sun sets over the mountains',
#  'a dragon with a red background',
#  'a man wearing a mask walks down a hallway',
#  'a man with a hat on his head',
#  'people walk through a flooded street in the town',
#  'a map of the earth with a line of latitudes',
#  'a man is standing on a mountain with a camera',
#  'a newspaper with a newspaper headline on it',
#  'a woman is picking tea leaves in a field',
#  'the location of the united states and mexico',
#  'a man sitting outside of a building with flowers and books',
#  'a man in a suit and tie sitting at a table',
#  'the logo for medviss, a medical device that is used to monitor patients',
#  'a man in a suit and tie',
#  'a man in a blue tank top is holding a flashlight',
#  'a man wearing a face mask and a woman wearing a face mask',
#  'a facebook page with a windmill in the background',
#  'a tree stump in the middle of a forest',
#  'launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch launch',
#  'a man in a blue shirt and hat speaking into a microphone',
#  "a horse with christmas lights on it's head",
#  'a man with a beard and a beard sitting at a table',
#  'a group of people holding flags and flags',
#  'people holding signs and holding signs in the street',
#  'a gi gi gi gi gi gi gi gi gi gi gi gi gi gi gi gi gi gi gi',
#  'a graphic showing the steps to start a business',
#  'a polar bear is sitting on an iceberg',
#  'spread of the wuhanus in china',
#  'a man swimming in the ocean',
#  'a man in a suit and tie talking to another man',
#  "a robot with a heart on it's chest",
#  'a mosquito with a red head and a black head',
#  'abstract background with glowing squares and squares',
#  'a black and white photo of a building',
#  'a woman is laying on her bed with a pillow',
#  'shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell shell',
#  'blockchai awards logo',
#  'a woman in a dress and shoes is walking through a store',
#  'paris hilton at the 2014 global global poker tournament',
#  'a logo for the company, the company is seen in this image',
#  'covidl risk associated ascounts and covidl death',
#  'a man sitting in a chair holding a microphone',
#  'the average temperature of the earth is shown in this graphic',
#  'california gov gov - fergy - fe',
#  'neon neon frame with hand holding a glowing light',
#  'a line graph shows the number of people who have been in the past',
#  'russian president vladimir putin gestures during a news conference in moscow',
#  "a young girl holding a sign that reads,'you cannot to be a victim '",
#  'a large ship is docked in the water',
#  'a fire burns in the forest near the village of kalo',
#  'the ice is melting in the arctic sea',
#  'a woman is sitting in front of a television screen',
#  'a man standing in front of a screen with a presentation on it',
#  'an elephant standing in a field of grass',
#  'coronavirus covidd e e e e e e e e e e e e e e e',
#  "the text on the phone reads,'no, no, no, no, no, no,",
#  "a bat with its mouth open and it's teeth missing",
#  'what is the coronavirus?',
#  'a man with a beard and a pink shirt',
#  'the cover of the book, the world of the world',
#  'the infographic energy station coloring book',
#  'a woman in a red shirt and blue gloves is petting a cat',
#  'a graphic showing the percentage of water pollution in the us',
#  'a man wearing a red face mask in a car',
#  'a flyer for the green city event',
#  'the cover of the book, the art of the body',
#  'bitcoin chart showing bitcoin and bitcoin',
#  'a white and black device on a table',
#  'a poster with a diagram of the different types of the different types of the human body',
#  'how to identify the best blockchain investments',
#  'the honda cr - v is parked on a street',
#  'the earth is covered in dust and dust, and the weather is still in the air',
#  "a quote from the author of the book,'there's a mixture of fear and anger it",
#  'a colorful number 9 surrounded by confectional confectional confectional confe',
#  'a screenshot of the texting app',
#  "the cover of the book,'blue green cities '",
#  'a group of people standing around a man in a white shirt',
#  "a screenshot of a text message with the words'i love you '",
#  'dr kumar on the web',
#  'a group of people standing around a fire',
#  'a blue background with the words adk antimatswi',
#  'three time magazine covers with a man in a suit and a woman in a suit',
#  'etherer upgrade',
#  'a bunch of receipts sitting on top of a table',
#  'a woman in a red sweater sits on rocks near a stream',
#  'two men in suits and ties are smiling',
#  'top 10 most trending aions',
#  'allwf is organized in maharashtra',
#  'a man in a suit standing in front of a plant',
#  'a woman with a hat on her head holding a pile of money',
#  'the first framer 2 0 series',
#  'a woman sitting on a chair in front of a large screen',
#  'thank to our team for their work on the new website',
#  'the beatles poster',
#  'the lancet - the lancet',
#  'the story of environmental record',
#  'a blue background with a white text that reads reduce your risk',
#  'a person is reaching their hand out to the rain',
#  'the google logo is seen at the google headquarters in san, califo',
#  'a light that is shining in the dark',
#  'a woman and a man sitting on a couch',
#  'a sunset with the words lg energy in the middle',
#  'hand sanze with hand sanze',
#  'a fire burns in the hills above santa feli, california',
#  'a group of people standing in a room',
#  'a man is seen on the sidewalk as he tries to get into his car',
#  'a lightning strikes in the sky above a city',
#  'a white background with the words queensland and queensland',
#  "a black and white image of a text that reads,'master for regenties '",
#  'a woman standing on a stage in front of a large screen',
#  'a presentation on the topic of the energy industry',
#  'people stand in front of a burning tree',
#  "a black and white typeface with the words,'a great place to be '",
#  'a man is lying down on the ground with his head in his hands',
#  'the timeline of the new mobile app',
#  'a cartoon character with a sad expression',
#  'a group of people standing around a classroom',
#  'the sims sims sims sims sims sims sims sims sims sims sims sims sims sims sims sims sims sims sims',
#  'a panel discussion with dr david kreg, dr david kreg, dr david kre',
#  'a robot is running in a room with other robots',
#  'a man in a blue shirt and black pants stands on a stage',
#  'a group of people walking down a street holding flags',
#  'a large room full of people',
#  'guidance on use of serrings',
#  'a woman in a blue uniform with an american flag',
#  'the amazon rainforest is home to a number of rainforests',
#  'a black background with a green border and a white border',
#  'a col of books with the title of the book',
#  'a woman in a blue dress and a man in a black suit',
#  'a cartoon depicting a man in a red hat and a man in a blue jacket',
#  'a man in a leather jacket and jeans is standing in front of a neon colored background',
#  'the syndicate - the syndicate - the syndicate - the syndicate - the syndicate - the syndicate - the syndicate',
#  'a man in a yellow jacket',
#  'the article is about the benefits of vitamin and vitamin',
#  'top 5 trend token as a',
#  'a small tree in the middle of a field',
#  'a cartoon character with a camera and a capt that reads, ` ` ` ` ` ` ` `',
#  'a colorful sculpture in the middle of a field',
#  'a map with the names of countries and countries',
#  'a diagram of the different types of the signal signal',
#  'a large group of fish swimming over a coral reef',
#  'vaccines protect us from disease at every stage of life',
#  "pelosa says she's not a'good'person",
#  'a brochure of a woman fishing',
#  'a col of images of a plane being loaded',
#  'a tv screen with a man on it',
#  'a mountain with trees and clouds in the background',
#  'a diagram showing the temperature of a temperature of a temperature of a temperature of a temperature of a temperature',
#  'bat night at the bat house',
#  'two women in traditional african clothing',
#  'the spacex falcon 4 rocket lifts off from the launch pada on saturday, july 12, 2019',
#  'a group of people sitting in chairs in a room',
#  'the average number of hetted deaths in uk is expected more than than than than than than than than',
#  'the national climate change website',
#  'batman car concept',
#  'the text in the text box is a blue background with a white background',
#  'an news flash logo',
#  "the cover of the book, the world's greatest",
#  'a woman standing in front of a building',
#  'a cartoon character in jail holding a dollar coin',
#  'a boat with orange smoke coming out of it',
#  'a large iceberg floating in the water',
#  'a pile of boxes with a cell in it',
#  'a man wearing a face mask and looking at his cell',
#  'a field with trees and grass in the background',
#  'a woman smiling with the words hip talk on her face',
#  'a woman in a white coat and black shirt',
#  'a windmill with the words wild wind syndrome',
#  'the ia and climate change',
#  'the twitter profile of a man with a beard and mustache',
#  'a group of men sitting around a table',
#  'three girls standing on the beach in front of the ocean',
#  'food security in the world',
#  "a phone with the words, ` `'and a pile of money",
#  'a young boy wearing a hat and scarf',
#  'a man sitting in front of a christmas tree',
#  'pope benedict is pictured during a mass at the vatican vatican vatican vatican vatican vatican vatican vatican vatican vatican vatican',
#  'a woman and a man are standing in front of a wall with a sign that says protect yourself',
#  'hierarchy of the hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy hierarchy',
#  'a man in a suit standing next to a cloud with gears on it',
#  'a man wearing a green vest and black pants',
#  'a man in a suit and tie sitting at a table',
#  'a man in a black jacket and white shirt sitting at a table',
#  'a woman with sunflowers on her head',
#  "people holding up a sign that says'fake planet '",
#  'a man in a red shirt and black jacket',
#  'visual cloud services',
#  'a man in a white shirt and glasses is talking to a woman',
#  'a man sitting in a chair with a red hat on',
#  'a photo of a factory with a smokestak and a photo of a factory with a smokesta',
#  "a text that reads,'every is a data '",
#  'a large group of fish swimming over a coral reef',
#  'a woman wearing a mask and a white jacket',
#  'a person holding a bottle of liquid in a box',
#  'a poster with the numbers of the countries',
#  'a woman standing at a podium with a sign',
#  'the new world of crypt',
#  'the chart shows the number of covids in the us',
#  'a man and woman standing at a podium',
#  'data and data visual data visual data visual data visual data visual data visual data visual data visual data visual',
#  'a truck driving down a hill with logs',
#  'a man in a green jacket is standing in front of a yellow wall',
#  'a man in a mask is sitting at a table',
#  'the logo for the ice tract',
#  "a cartoon girl holding a book with the word's on it",
#  'a group of people sitting around a table',
#  'a woman wearing a face mask with colorful crystals',
#  'a video chat with several people on the screen',
#  'emergency personnel gather at the scene of a fatal fire in the bronx on monday, oct 11, 2019',
#  'daily revenues turnover of new cases ensure upward decline in covid',
#  'a man is working in the garden with animals and plants',
#  'bad news wrap in the corona crisis',
#  'the earth from space',
#  'google search results for google search results',
#  'a group of viruses',
#  "m's priale prati ltd",
#  'a man in a suit is sitting on a chair',
#  'a video screen showing a dog running through the grass',
#  'a map of cotham',
#  'a man is playing basketball on a court',
#  'a man in a suit and tie standing at a podium',
#  'a woman is standing in the sand with her belongings',
#  'an aerial view of the lake and mountains',
#  'a stack of boxes with labels on them',
#  'a man is standing on the floor with a blue sheet',
#  'two books on a table',
#  'a yellow background with the words coronaviruss and a yellow background with the words coronaviruss',
#  'fox news on fox news',
#  'the logo for the seoul music awards',
#  'a blue background with the words next for blockchain applications encryption track',
#  "a twitter account with a message that reads,'i'm o'tweet",
#  'two young girls sitting on the ground in front of a colorful wall',
#  'bitcoin bitcoin bitcoin bitcoin bitcoin bitcoin bitco',
#  'a hedge eating a piece of food on a field',
#  'a woman holding signs in the street',
#  'two women standing in front of a map',
#  'a cartoon picture of a man in a suit and tie',
#  'a white delivery truck parked on the side of a street',
#  "a rainbow with the words, every you can't - shirt",
#  'weekly mix january 8, 2019',
#  'a diagram of the timeline of the european union',
#  'a woman wearing glasses and a yellow shirt',
#  'a white table',
#  'a person holding a pen in their hand',
#  'a group of people sitting around a table',
#  'a blue painting with white and black paint',
#  "the cover of the book,'the history of the world '",
#  'a man sitting in a chair in a room',
#  'a surgeon holding a dollar bill in his hand',
#  'a hand holding a book with a fingerprint',
#  'the image shows a person with a futuristic head and a futuristic body',
#  'four common configurations',
#  'a poster for the trade show',
#  'alberta has dedicated to coronavirus',
#  'a street with a traffic light and a barrier',
#  'the late show - the late show',
#  'a man walking across a dry field',
#  'two screens showing the same text and the same text',
#  'a screenshot of a text message that reads ` ` ` ` ` ` ` ` ` ` `',
#  'a young man with a red jacket and black shirt',
#  'the global energy market infographic',
#  'a usb that is connected to a usb',
#  'a brain with a broken brain and a broken brain',
#  'the exterior of the new store, the new store, in downtown',
#  'a screenshot of a green screen with the text energy',
#  'students in a classroom at a school in mumbai',
#  'a group of people standing around a tree',
#  'a large pipe with a hole in the center',
#  'a sign that says, and still some people believe climate',
#  'what is the city of god?',
#  'a gun in a game',
#  'a child in a raincoat holding a dolphin',
#  'white house corona crisis',
#  'the fore - trading strategy for the us dollar',
#  'a man in a green shirt',
#  'a large white boat in the water',
#  'a cartoon character with a red and white robot',
#  "the poster for the movie,'digital rights '",
#  'a pie chart with the percentage of the data',
#  'a group of people standing around a tree',
#  'people watch as the fire burns through the hills',
#  "a woman with her hand on her face, with the words'mys vas'and '",
#  'we are ready for transition to a 10 % energy economy economy economy economy economy economy economy economy economy economy',
#  'a skull in a space suit with a flower on his head',
#  'two women sitting on a chair with their legs crossed',
#  'a screenshoter with the bitcoin option',
#  'vacines with professor van',
#  'a small device is sitting on a table',
#  'a little girl holding a baby in her arms',
#  "a city with a quote that reads,'unventes move over the top of pollution per",
#  'a group of people standing in front of a poster',
#  'three women sitting at a table with a box of paint',
#  'the flyer for the startup startup startup startup startup startup startup startup startup startup startup startup startup startup startup startup',
#  'vaccines are smart, but not in the us',
#  'a view of the terminal',
#  'the article in the hindi newspaper',
#  'healthy soils provide the largest sore of earth',
#  'a screenshot of a text message with the texting app',
#  'a fire burns in the mountains behind a parking lot',
#  'a large crowd of people sitting in chairs in a room',
#  'a man in a hat and glasses holds a picture of a kangaroo',
#  'a man with a beard and a blue shirt',
#  'a police tape is seen in front of a police car',
#  "the global computing market is growing, but it's not going to the next",
#  'the logo for the crypt company',
#  'a map with the words who countries have the most da',
#  "a quote from the economist on the cover of the economist's book",
#  'the cycle of security',
#  'a man walking down a street with a bunch of money',
#  'senate senate committee on senate committee on senate committee',
#  "a green flag with the words,'leading way to low carbon future '",
#  'a rocky beach with waves crashing on rocks',
#  'a nurse and a patient in a hospital room',
#  'a man on a stage doing a trick',
#  'a graph graph with the number of people who have been in the past',
#  'a receipt with a receipt on it',
#  'toe production single single',
#  'a graph of the number of different types of the human genome']

# %%
captions_file = "/Users/onurdenizguler/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive/data/CT23_1A_checkworthy_multimodal_english_test_gold/captions_gold.txt"
captions = []
with open(captions_file, "r") as f:
    for line in f:
        captions.append("".join(line.split(',')[:-1]))

# %%
prompt_template = """
You are a social media rules and regulations editor whose job is to read tweets and look at captions that describe the accompanying image to understand whether the tweet requires any fact checking. If fact checking is required, you print out “final_decision” = ;;;Yes;;;, if it is not required, you print out “final_decision” =  ;;;No;;;. 

Your guidelines:

“step_1”: First look at the “text” of a tweet. It contains a verifiable claim if and only if: it states a definition OR mentions a quantity in the present or in the past OR makes a verifiable prediction about the future OR references laws, procedures, and rules of operation OR states correlation or causation.

“step_2”: If the tweet contains a verifiable claim, then you check whether it requires fact checking. The claim requires fact checking if and only if: it appears to be false OR is of public interest or appears to be harmful: can negatively affect society as a whole, but also specific persons, companies, products.
If both “step_1” and “step_2” hold, then you label the tweet as fact checkable. So you say “final_decision” = ;;;Yes;;;. If not, you then look at the image caption and the OCR text:

“step_3”: Look at the image. Does the image contribute to establish if a tweet has a factually-verifiable claim? It does if and only if: there exists a piece of evidence (e.g. an event, action, situation or a person’s identity) OR illustration of certain aspects in the claim text OR the OCR text contains a claim. If the OCR text contains a claim you apply “step_1” and “step_2” on it to finalize your decision.

your_current_tweet = [
“text”: ‘{text}’,
“image_caption”: {caption},
"ocr_text": ‘{ocr_text}’,
]

“step_1”: You look at the text of the tweet. Does it contain a verifiable claim?
“step_2”: If it contains a verifiable claim, does it require fact checking?
“step_3”: Do the image caption or the OCR make you think that this tweet requires fact checking?
“final_decision”=
"""

# %%
import re
gold_prompts = []
for text, ocr_text, caption in zip(texts["gold"], ocr_texts["gold"], captions):
    ocr_text = re.sub('\n', '', ocr_text)
    ocr_text = re.sub('"', '', ocr_text)
    ocr_text = re.sub("'", '', ocr_text)
    text = re.sub('\n', '', text)
    text = re.sub('"', '', text)
    text = re.sub("'", '', text)
    gold_prompts.append(prompt_template.format(text=text, ocr_text = ocr_text, caption=caption))


prompts_gold_file = "prompts_gold.txt"
for idx, prompt in enumerate(gold_prompts):
    filename = "prompts_gold/" + str(idx) + ".txt"
    with open(filename, "w") as f:
        f.write(prompt)

# %%
import openai
openai.api_key = "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"

full_responses = []
responses = []
last_processed_prompt = -1

# %%
prompt
# Out:
# '\nYou are a social media rules and regulations editor whose job is to read tweets and look at captions that describe the accompanying image to understand whether the tweet requires any fact checking. If fact checking is required, you print out “final_decision” = ;;;Yes;;;, if it is not required, you print out “final_decision” =  ;;;No;;;. \n\nYour guidelines:\n\n“step_1”: First look at the “text” of a tweet. It contains a verifiable claim if and only if: it states a definition OR mentions a quantity in the present or in the past OR makes a verifiable prediction about the future OR references laws, procedures, and rules of operation OR states correlation or causation.\n\n“step_2”: If the tweet contains a verifiable claim, then you check whether it requires fact checking. The claim requires fact checking if and only if: it appears to be false OR is of public interest or appears to be harmful: can negatively affect society as a whole, but also specific persons, companies, products.\nIf both “step_1” and “step_2” hold, then you label the tweet as fact checkable. So you say “final_decision” = ;;;Yes;;;. If not, you then look at the image caption and the OCR text:\n\n“step_3”: Look at the image. Does the image contribute to establish if a tweet has a factually-verifiable claim? It does if and only if: there exists a piece of evidence (e.g. an event, action, situation or a person’s identity) OR illustration of certain aspects in the claim text OR the OCR text contains a claim. If the OCR text contains a claim you apply “step_1” and “step_2” on it to finalize your decision.\n\nyour_current_tweet = [\n“text”: ‘Beware of #CustomerCareFrauds One wrong Google search can wipe out your entire bank account.Always visit Official websites of a company for customer care numbersDont Click suspicious links.Never Share your Banking details with suspicious websites. https://t.co/B6E7kPE0vv’,\n“image_caption”: \'the article in the paper\',\n"ocr_text": ‘నెట్టింట్లో సైబర్ దొంగలుహెల్ప్లైన్ నెంబర్లతో సరికొత్త దందా • కస్టమర్ కేర్ నెంబర్లతో అప్రమత్తత అవసరంహైదరాబాద్ సిటీ, ఏప్రిల్ 22(ఆంధ్రజ్యోతి): నగరానికి చెందినకొవిడ్ రోగి హోమ్ ఐసోలేషన్ సదుపాయాలు లేకపోవడంతో ఓయో హోటల్ను సందర్శించాలనుకున్నాడు. గూగుల్లో వెదికి ఓ నెంబరుక్కు ఫోన్ చేశాడు.ఆ నెంబర్ నుంచి ఎలాంటి స్పందనాలేదు. కాసేపటికి మరో నెంబర్ నుంచిఫోన్ వచ్చింది. ఓయో హోటల్స్ అని పరిచయం చేసుకున్న అతడు, మాటలలోపెట్టి బ్యాంకు ఖాతా వివరాలు తెలుసుకున్నాడు. మాట్లాడుతూనే ఖాతా ఖాళీ చేసేశాడు. తరువాత ఫోన్ స్విచ్చాఫ్ చేశాడు. కేసుసైబర్ క్రైమ్క వెళ్లింది.రమేష్ అమెజాన్ ట్రిమ్మర్ ఆర్డర్చేశాడు. కానీ వేరేది వచ్చింది. దాన్ని ఎలారిటర్న్ చేయాలో తెలియక గూగుల్లో అమెజాన్ కస్టమర్ కేర్ నెంబర్ కోసం వెదికాడు.ఓ నెంబర్ దొరికితే దానికి డయల్ చేసి,ప్రొడక్ట్ వెనక్కి తీసుకుని డబ్బులు రిటర్న్చేయమని కోరాడు. అవతలి వ్యక్తి ఏ విధంగారిటర్న్ చేయాలో తాను చూపిస్తానంటూ ఎనీడెస్క్ అప్లికేషన్ను సిస్టమ్ ఇన్స్టాల్ చేసుకోమని చెప్పాడు. రమేష్ అతను చెప్పినట్లేచేశాడు. బ్యాంకు ఖాతా ఖాళీ అయ్యాక మోసపోయానని తెలుసుకున్నాడు.ఈ తరహా కేసులు నగరంలో పెద్ద సంఖ్యలోనే జరుగుతున్నాయి. చేతిలో ఫోన్, దానిలోడాటా ఉంటే చాలు, చక్కబెట్టని పనంటూలేదిప్పుడు అన్నట్లుగా పరిస్థితులు ఉన్నాయి..అదే మోసగాళ్లకు కొత్త అవకాశాలనూఅందిస్తోంది.మోసగాళ్ల బారినపడితే ఖల్లాస్షాపింగ్, ట్రావెలింగ్ ఫుడ్.. ఒకటేంటి దేనికైనా సరే ఇప్పుడు యాప్ లు ఉన్నాయి. అదనపు సమాచారం కావాలంటే గుగూల్, బింగ్లాంటి సెర్చ్ ఇంజిన్లు కూడా సహాయపడటానికి ముందున్నాయి. ఇవే సైబర్ క్రిమినల్స్తమదైన రీతిలో మోసాలు చేసేందుకు కూడాఉపయోగపడుతున్నాయి. సైబర్ క్రిమినల్స్సెర్చ్ ఇంజిన్ ఆప్టిమైజేషన్ (ఎస్ఈఓ) టెక్నిక్స్వినియోగించడంతోపాటు తమ కాంటాక్ట్నెంబర్లను కస్టమర్ కేర్ నెంబర్లుగా కనిపించేలా ప్రకటనలకు డబ్బులు సైతం చెల్లిస్తున్నారన్నారు. జూమ్ సైబర్ సెన్స్ సీఈవోఎంహెచ్ నోబెల్. పే యాప్లతోపాటు ఈకామర్స్ లాంటి ప్రాచుర్యం పొందిన యాప్ లు/ వెబ్సైట్ల పేర్లను వీరు వినియోగించుకుంటున్నారు.మోసాలు జరిగే తీరు ఇలా..తమ సమస్య పరిష్కారం కోసంవినియోగదారులు గుగూల్ సెర్చ్లో వెదికినప్పుడు తమకు కనిపించిన నెంబరుసరిగా నిర్ధారించుకోకుండా కాల్ చేస్తేమోసం జరిగేందుకు అవకాశం ఉంది.నేరగాళ్లు సంస్థకు చెందిన అసలైనప్రతినిధుల్లా మాట్లాడి వివరాలు రాబట్టుకునే ప్రయత్నం చేస్తారు. బాధితులకునకిలీ లింకులను ...

# %%
with open("prompts_gold/276.txt", "r") as f:
    gold_prompts[713] = "".join(f.readlines())

# %%
gold_prompts.index(prompt)
# Out:
# 713

# %%
counter = 0
for prompt in gold_prompts[last_processed_prompt+1:]:
  counter += 1
  response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
          #{"role": "system", "content": "You are a social media rules and regulations editor."},
          {"role": "user", "content": prompt},
      ]
  )
  full_responses.append(response)
  responses.append(response['choices'][0]['message']["content"])
  if gold_prompts.index(prompt)%10 == 0:
    print(gold_prompts.index(prompt))
  last_processed_prompt = gold_prompts.index(prompt)
  if counter ==200:
    break
# Out:
# 720
# 730

# %%
responses[580]
# Out:
# '“step_1”: The text of the tweet contains several verifiable claims: \n1. “£1m of cocaine that was hidden in a box of face masks was seized by experienced officers at the Channel Tunnel yesterday.”\n2. “Criminal networks are trying to exploit the #coronavirus outbreak for their own benefit.”\n3. “Border Force and @NCA_UK are working together to stop them.”\n\n“step_2”: These verifiable claims may require fact checking as they involve illegal activities and the actions taken by law enforcement agencies. Additionally, the claim about criminal networks exploiting the coronavirus outbreak is of public interest.\n\n“step_3”: The image caption, "a pile of boxes with a cell in it," does not directly contribute to establishing the veracity of the verifiable claims.\n\n“final_decision” = ;;;Yes;;;'

# %%
import random
import numpy as np
preds = []
for response in responses:
    if "no" in response.lower().split(";;;"):
        preds.append(0)
    elif "yes" in response.lower().split(";;;"):
        preds.append(1)
    else:
        preds.append(1) if "yes" in response.lower() else preds.append(0) if "no" in response.lower() else preds.append(random.choice([0, 1]))

preds = np.array(preds)

focus_labels = split_to_labels["gold"][:len(preds)]

arg_pos = np.argwhere(focus_labels == 1).flatten()
arg_neg = np.argwhere(focus_labels == 0).flatten()
TP = sum(preds[arg_pos] == 1)
FP = sum(preds[arg_neg] == 1)
FN = sum(preds[arg_pos] == 0)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f1 = 2*(precision*recall)/(precision+recall)
print(precision, recall, f1)
# Out:
# 0.75 0.5740072202166066 0.6503067484662576

# %%
with open("explains_gold.pickle", 'rb') as handle:
    mypreds = pickle.load(handle)

# %%
import pickle
with open("captions_gold.pickle", 'wb') as handle:
    pickle.dump(captions, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import random
import numpy as np
preds = []
explains = [] 
for response in responses:
    if "no" in response.lower().split(";;;"):
        preds.append(0)
    elif "yes" in response.lower().split(";;;"):
        preds.append(1)
    else:
        preds.append(1) if "yes" in response.lower() else preds.append(0) if "no" in response.lower() else preds.append(random.choice([0, 1]))
    explains.append(response.split("final_decision")[0])
preds = np.array(preds)

focus_labels = split_to_labels["gold"][:len(preds)]

arg_pos = np.argwhere(focus_labels == 1).flatten()
arg_neg = np.argwhere(focus_labels == 0).flatten()
TP = sum(preds[arg_neg] == 0)
FP = sum(preds[arg_pos] == 0)
FN = sum(preds[arg_neg] == 1)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f1 = 2*(precision*recall)/(precision+recall)
print(precision, recall, f1)
# Out:
# 0.7748091603053435 0.8845315904139434 0.8260427263479145

# %%
len(preds)
# Out:
# 736

# %%
if user in users[:2]:
    data_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive/data/CT23_1A_checkworthy_multimodal_english_{version}"
    cw_dir = f"/Users/{user}/Library/CloudStorage/GoogleDrive-check.worthiness@gmail.com/My Drive"

else:
    data_dir = f"/home/jockl/Insync/check.worthiness@gmail.com/Google Drive/data/CT23_1A_checkworthy_multimodal_english_{dataset_version}"
    cw_dir = "/home/jockl/Insync/check.worthiness@gmail.com/Google Drive"

features_dir = f"{data_dir}/features"
labels_dir = f"{data_dir}/labels"
models_dir = f"{cw_dir}/models/vanillann_hyperparam_search"
split_to_labels = {split: 
                   np.load(f"{labels_dir}/{split}_labels_{dataset_version}.pickle", allow_pickle=True) if split != "gold" else np.load(f"{labels_dir}/{split}_labels.pickle", allow_pickle=True)
                   for split in SPLITS}

# %%
responses[210]
# Out:
# '1) The text of the tweet does not contain a verifiable claim. It includes a quote from @novogratz but does not make any specific verifiable statements.\n2) Since there is no verifiable claim in the tweet, fact checking is not required.\n3) The image caption and the OCR text do not provide any additional information that suggests fact checking is needed.\nFinal Decision: ;;;No;;;'

# %%
for idx, prompt in enumerate(gold_prompts[210:]):
  if idx%20 == 0:
    print(idx)
  response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
          #{"role": "system", "content": "You are a social media rules and regulations editor."},
          {"role": "user", "content": prompt},
      ]
  )
  full_responses.append(response)
  responses.append(response['choices'][0]['message']["content"])
# Out:
# 0
# 20
# 40
# 60
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[179], line 4
#       2 if idx%20 == 0:
#       3   print(idx)
# ----> 4 response = openai.ChatCompletion.create(
#       5   model="gpt-3.5-turbo",
#       6   messages=[
#       7         #{"role": "system", "content": "You are a social media rules and regulations editor."},
#       8         {"role": "user", "content": prompt},
#       9     ]
#      10 )
#      11 full_responses.append(response)
#      12 responses.append(response['choices'][0]['message']["content"])
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/openai/api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/openai/api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/openai/api_requestor.py:763, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     761 stream_error = stream and "error" in resp.data
#     762 if stream_error or not 200 <= rcode < 300:
# --> 763     raise self.handle_error_response(
#     764         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     765     )
#     766 return resp
#
# InvalidRequestError: This model's maximum context length is 4097 tokens. However, your messages resulted in 5039 tokens. Please reduce the length of the messages.
